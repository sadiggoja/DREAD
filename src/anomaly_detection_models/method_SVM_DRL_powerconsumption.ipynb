# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.svm import OneClassSVM
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
# !gdown --id 1reCBidpAaci6CZnZOxfZHvWO_VMNK93W -O tmp.zip
# !unzip -q tmp.zip && rm tmp.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1reCBidpAaci6CZnZOxfZHvWO_VMNK93W
# To: /content/tmp.zip
# 100% 1.41M/1.41M [00:00<00:00, 131MB/s]

# %%
consumption=pd.read_csv("powerconsumption.csv")

# %%
consumption['Datetime'] = pd.to_datetime(consumption['Datetime'])
consumption.set_index('Datetime', inplace=True)

# %%
consumption
# Out:
#                      Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# Datetime
# 2017-01-01 00:00:00        6.559      73.8      0.083                0.051
# 2017-01-01 00:10:00        6.414      74.5      0.083                0.070
# 2017-01-01 00:20:00        6.313      74.5      0.080                0.062
# 2017-01-01 00:30:00        6.121      75.0      0.083                0.091
# 2017-01-01 00:40:00        5.921      75.7      0.081                0.048
# ...                          ...       ...        ...                  ...
# 2017-12-30 23:10:00        7.010      72.4      0.080                0.040
# 2017-12-30 23:20:00        6.947      72.6      0.082                0.051
# 2017-12-30 23:30:00        6.900      72.8      0.086                0.084
# 2017-12-30 23:40:00        6.758      73.0      0.080                0.066
# 2017-12-30 23:50:00        6.580      74.1      0.081                0.062
#
# ...

# %%
features = ['Temperature', 'Humidity', 'WindSpeed', 'GeneralDiffuseFlows', 'DiffuseFlows',
            'PowerConsumption_Zone1', 'PowerConsumption_Zone2', 'PowerConsumption_Zone3']
df=consumption.copy()
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[features])

# %%
one_class_svm = OneClassSVM(nu=0.05)
# Fit the model on the normal data (inliers)
one_class_svm.fit(scaled_data)
# Out:
# OneClassSVM(nu=0.05)

# %%
predictions = one_class_svm.predict(scaled_data)

# Convert predictions to 1 for normal, -1 for anomaly
predictions = (predictions == 1).astype(int)

# %%
print((predictions == 0).sum())
print((predictions == 1).sum())
# Out:
# 2618
# 49798

# %%
df['anomaly_score']=predictions

# %%
df
# Out:
#                      Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# Datetime
# 2017-01-01 00:00:00        6.559      73.8      0.083                0.051
# 2017-01-01 00:10:00        6.414      74.5      0.083                0.070
# 2017-01-01 00:20:00        6.313      74.5      0.080                0.062
# 2017-01-01 00:30:00        6.121      75.0      0.083                0.091
# 2017-01-01 00:40:00        5.921      75.7      0.081                0.048
# ...                          ...       ...        ...                  ...
# 2017-12-30 23:10:00        7.010      72.4      0.080                0.040
# 2017-12-30 23:20:00        6.947      72.6      0.082                0.051
# 2017-12-30 23:30:00        6.900      72.8      0.086                0.084
# 2017-12-30 23:40:00        6.758      73.0      0.080                0.066
# 2017-12-30 23:50:00        6.580      74.1      0.081                0.062
#
# ...

# %%
plt.plot(df.index, df['PowerConsumption_Zone1'])
plt.scatter(df.index[df['anomaly_score'] == 0], df['PowerConsumption_Zone1'][df['anomaly_score'] == 0], c='red')
plt.xlabel('Date')
plt.ylabel('PowerConsumption_Zone1')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'gamma': [0.0001, 0.001, 0.01, 0.1, 1],
              'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],}
one_class=OneClassSVM(nu=0.05)
grid_search = GridSearchCV(estimator=one_class, scoring='neg_mean_squared_error', param_grid=parameters, cv=5)
grid_search.fit(scaled_data)
best_parameters = grid_search.best_params_
print(best_parameters)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: _BaseScorer.__call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# ...

# %%
# Out:
# anomaly_score
# 0     2621
# 1    49795
# dtype: int64

# %%
# plt.plot(df.index, df['PowerConsumption_Zone1'])
# plt.scatter(df.index[df['anomaly_score'] == 0], df['PowerConsumption_Zone1'][df['anomaly_score'] == 0], c='red')
# plt.xlabel('Date')
# plt.ylabel('PowerConsumption_Zone1')
# plt.show()

# %%
import joblib

# %%
model_filename = 'SVM.joblib'
joblib.dump(one_class_svm, model_filename)
# Out:
# ['SVM.joblib']
